# %%
import pandas as pd

# %%
res = pd.read_csv('../data/idmdl/emotions_summarised_date_W3.csv')

# %%
res.head()
# Out:
#          date                                           emo_prob   novelty  \
# 0  2022-07-01  [0.4102841628033776, 0.20283810770628943, 0.27...  0.000000
# 1  2022-07-02  [0.40084572219478715, 0.21917917825569294, 0.2...  0.000000
# 2  2022-07-03  [0.4037160081303834, 0.20537370617679093, 0.27...  0.000000
# 3  2022-07-04  [0.40380313076118163, 0.2118206568904984, 0.26...  0.000209
# 4  2022-07-05  [0.4058128010562254, 0.21283269690997658, 0.27...  0.000122
#
#    transience  resonance    nsigma    tsigma    rsigma
# 0    0.000269   0.000000  0.000000  0.000219  0.000000
# 1    0.000295   0.000000  0.000000  0.000198  0.000000
# 2    0.000274   0.000000  0.000000  0.000084  0.000000
# 3    0.000188   0.000020  0.000006  0.000157  0.000082
# 4    0.000491  -0.000368  0.000070  0.000331  0.000200

# %%
df_emo.head()
# Out:
#    index     username               date_created  number_of_likes  \
# 0      0  Statsstyret  2022-11-25 13:28:38+00:00              1.0
# 1      1  Statsstyret  2022-11-24 05:37:56+00:00              9.0
# 2      2   snicolaidk  2022-11-23 16:56:54+00:00              2.0
# 3      3       Elsest  2022-11-23 15:03:55+00:00              2.0
# 4      4     Sahu2060  2022-11-17 06:16:26+00:00              4.0
#
#                                               tweets language party  \
# 0  Her er lidt ammo til kulturkrigen 😂\n\n#dkpolm...       da    KF
# 1  Hvad med vi får gang i et ordentligt retsopgør...       da    KF
# 2  @CKjersgaard @DebattenDR2 en anden der kan... ...       da    KF
# 3  @kasper2619 @PiaOlsen 2/2 belønne HUSEJERE, de...       da    KF
# 4  @RasmusJarlov Ps hvorfor ødelægger du det kons...       da    KF
#
#                                          clean_tweet  \
# 0  Her er lidt ammo til kulturkrigen 😂           ...
# ...

# %%
# turn date_created into datetime with only date
df_emo['date_created'] = pd.to_datetime(df_emo['date_created'], utc=True).dt.strftime("%Y-%m-%d")
# group by date and take the mean of the emotions
avg = df_emo.groupby('date_created').mean()
# Out:
# /var/folders/6v/9wx2wvns3pzd3h_jgjzm673r0000gn/T/ipykernel_41608/3381643673.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg = df_emo.groupby('date_created').mean()

# %%
avg
# Out:
#                       index  number_of_likes     Glæde  Overraskelse  \
# date_created
# 2022-07-01    277499.232367        16.338164  0.410284      0.202838
# 2022-07-02    298775.920061         9.359615  0.400846      0.219179
# 2022-07-03    303648.463542         7.594184  0.403716      0.205374
# 2022-07-04    304088.657831        11.835663  0.403803      0.211821
# 2022-07-05    282129.196776         9.708144  0.405813      0.212833
# ...                     ...              ...       ...           ...
# 2022-11-22    156848.319244         7.713014  0.471547      0.187834
# 2022-11-23    146392.373990         8.431341  0.428664      0.206910
# 2022-11-24    147802.514229         6.656515  0.442373      0.200685
# 2022-11-25    190933.590680         7.812343  0.441720      0.186895
# 2022-11-26    182775.976429         5.974286  0.426530      0.232534
#
#                  Vrede  Tristhed     Afsky     Frygt
# date_created
# 2022-07-01    0.275842  0.080166  0.011679  0.019191
# ...
